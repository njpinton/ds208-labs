# %% [markdown]
# # DS 208 &middot; Programming for Data Science &mdash; Week 1 Welcome Lab### Where you're starting fromThis is **not a test** and it is **not graded**. It exists so I know what the roomalready knows before Week 2, and so you find out now &mdash; not in Week 6 &mdash; whetheranything here is unfamiliar.**How long:** about 30 minutes. **What you need:** a browser. Nothing to install.Work top to bottom. If a cell does not run, that is information too &mdash; write down whatit said and move on. Nobody is expected to finish the Stretch section.

# %% [markdown]
# ---## Part 0 &middot; Does this thing workClick the cell below and press **Shift+Enter**. That runs it.

# %%
import sys, platformprint("Python", sys.version.split()[0])print("Running on", platform.system())print("\nIf you can read this, Colab works and you are set for Week 1.")

# %% [markdown]
# ---## Part 1 &middot; Change one thingBelow, `YOUR_NAME` and `HOURS_PER_WEEK` are **variables**. Change both to real values,then run the cell.`HOURS_PER_WEEK` is how many hours a week you realistically have for this course. Behonest &mdash; I use the spread to decide how much I can set.

# %%
YOUR_NAME = "change me"HOURS_PER_WEEK = 0print(f"{YOUR_NAME} has about {HOURS_PER_WEEK} hours a week for DS 208.")print(f"Over 12 weeks that is roughly {HOURS_PER_WEEK * 12} hours.")

# %% [markdown]
# ---## Part 2 &middot; Read an errorThe next cell is **broken on purpose**. Run it. It will fail, and that is correct.Errors in Python are not punishment; they are the most specific help you will get allsemester. The trick is that the useful line is usually the **last** one.

# %%
temperatures = [28, 31, 29, 33]print("Highest today:", temperatures[4])

# %% [markdown]
# **Answer here** (double-click to edit this cell):1. What is the **last line** of the error saying? Copy it.   &rarr; *your answer*2. In plain words, what went wrong?   &rarr; *your answer*3. `temperatures` has 4 numbers in it. What number should be inside the square brackets   to get the last one? (You may guess. Then try it above and see.)   &rarr; *your answer*

# %% [markdown]
# ---## Part 3 &middot; What you have used beforeNo wrong answers, and no advantage to overstating it. Replace each `-` with one of:**never heard of it** / **heard of it** / **used it once or twice** / **use it regularly**.| Tool | You ||---|---|| Excel or Google Sheets | - || Python | - || Jupyter or Colab notebooks | - || pandas | - || Git or GitHub | - || SQL | - || R, Stata, or SPSS | - |**Anything else you have used that is not listed:**&rarr; *your answer***One sentence: what do you want out of this course?**&rarr; *your answer*

# %% [markdown]
# ---## Stretch &mdash; optionalStop here if you like; the required part is done and nothing below affects anything.These exist so that if you *have* programmed before, I can see that too, and pitch thefirst few weeks accordingly.

# %% [markdown]
# ### Stretch 1 &middot; Repeat somethingPrint the numbers 1 to 5, each on its own line. There are several right answers.

# %%
# your code here

# %% [markdown]
# ### Stretch 2 &middot; Fix the bugThis is meant to return the average of a list. It does not. Find the mistake and fix it.

# %%
def average(numbers):    total = 0    for n in numbers:        total = n          # <- something here is wrong    return total / len(numbers)print(average([2, 4, 6, 8]))   # should print 5.0

# %% [markdown]
# ### Stretch 3 &middot; A table`pandas` is the library this course spends the most time on. Run the first cell, thenanswer in the second.

# %%
import pandas as pddf = pd.DataFrame({    "student": ["A", "B", "C", "D", "E"],    "hours":   [3, 12, 6, 9, 1],    "course":  ["DS 208", "DS 208", "DS 227", "DS 208", "DS 227"],})df

# %%
# Show only the rows where course is "DS 208".# If you have never used pandas, leave this blank and move on.

# %% [markdown]
# ---## Submitting1. **File &rarr; Download &rarr; Download .ipynb**2. Open **https://portal.latarak.com/course/ds208/lab/1/submit**3. Sign in with your student number and upload the file.You can re-upload as often as you like before the deadline &mdash; the latest version isthe one kept. If you have not been given a password yet, ask your instructor.

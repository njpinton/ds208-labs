# %% [markdown]
# # DS 208 &middot; Programming for Data Science &mdash; Week 1 Welcome Lab
# ### Where you're starting from
#
# This is **not a test** and it is **not graded**. It exists so I know what the room
# already knows before Week 2, and so you find out now &mdash; not in Week 6 &mdash; whether
# anything here is unfamiliar.
#
# **How long:** about 30 minutes. **What you need:** a browser. Nothing to install.
#
# Work top to bottom. If a cell does not run, that is information too &mdash; write down what
# it said and move on. Nobody is expected to finish the Stretch section.

# %% [markdown]
# ---
# ## Part 0 &middot; Does this thing work
#
# Click the cell below and press **Shift+Enter**. That runs it.

# %%
import sys, platform

print("Python", sys.version.split()[0])
print("Running on", platform.system())
print("\nIf you can read this, Colab works and you are set for Week 1.")

# %% [markdown]
# ---
# ## Part 1 &middot; Change one thing
#
# Below, `YOUR_NAME` and `HOURS_PER_WEEK` are **variables**. Change both to real values,
# then run the cell.
#
# `HOURS_PER_WEEK` is how many hours a week you realistically have for this course. Be
# honest &mdash; I use the spread to decide how much I can set.

# %%
YOUR_NAME = "change me"
HOURS_PER_WEEK = 0

print(f"{YOUR_NAME} has about {HOURS_PER_WEEK} hours a week for DS 208.")
print(f"Over 12 weeks that is roughly {HOURS_PER_WEEK * 12} hours.")

# %% [markdown]
# ---
# ## Part 2 &middot; Read an error
#
# The next cell is **broken on purpose**. Run it. It will fail, and that is correct.
#
# Errors in Python are not punishment; they are the most specific help you will get all
# semester. The trick is that the useful line is usually the **last** one.

# %%
temperatures = [28, 31, 29, 33]

print("Highest today:", temperatures[4])

# %% [markdown]
# **Answer here** (double-click to edit this cell):
#
# 1. What is the **last line** of the error saying? Copy it.
#    &rarr; *your answer*
#
# 2. In plain words, what went wrong?
#    &rarr; *your answer*
#
# 3. `temperatures` has 4 numbers in it. What number should be inside the square brackets
#    to get the last one? (You may guess. Then try it above and see.)
#    &rarr; *your answer*

# %% [markdown]
# ---
# ## Part 3 &middot; About you
#
# Your background, what you want from the course and what you already know are collected
# **once** on the course portal rather than here, so they are not scattered across twelve
# notebooks:
#
# &rarr; [background questionnaire](https://portal.latarak.com/course/ds208/intake)
#
# It takes a few minutes and you only do it once. Your first lab submission unlocks after
# it is filled in.

# %% [markdown]
# ---
# ## Stretch &mdash; optional
#
# Stop here if you like; the required part is done and nothing below affects anything.
#
# These exist so that if you *have* programmed before, I can see that too, and pitch the
# first few weeks accordingly.

# %% [markdown]
# ### Stretch 1 &middot; Repeat something
#
# Print the numbers 1 to 5, each on its own line. There are several right answers.

# %%
# your code here

# %% [markdown]
# ### Stretch 2 &middot; Fix the bug
#
# This is meant to return the average of a list. It does not. Find the mistake and fix it.

# %%
def average(numbers):
    total = 0
    for n in numbers:
        total = n          # <- something here is wrong
    return total / len(numbers)


print(average([2, 4, 6, 8]))   # should print 5.0

# %% [markdown]
# ### Stretch 3 &middot; A table
#
# `pandas` is the library this course spends the most time on. Run the first cell, then
# answer in the second.

# %%
import pandas as pd

df = pd.DataFrame({
    "student": ["A", "B", "C", "D", "E"],
    "hours":   [3, 12, 6, 9, 1],
    "course":  ["DS 208", "DS 208", "DS 227", "DS 208", "DS 227"],
})
df

# %%
# Show only the rows where course is "DS 208".
# If you have never used pandas, leave this blank and move on.

# %% [markdown]
# ---
# ## Submitting
#
# 1. **File &rarr; Download &rarr; Download .ipynb**
# 2. Go to the [Week 1 submission page](https://portal.latarak.com/course/ds208/lab/1/submit)
# 3. Sign in with your student number and upload the file.
#
# You can re-upload as often as you like before the deadline &mdash; the latest version is
# the one kept. If you have not been given a password yet, ask your instructor.

# %% [markdown]
# # DS 208 &middot; Programming for Data Science &mdash; Week 12 Lab
# ## Integrative Project Workbench
#
# This is your **project workbench**, not a set of exercises. It walks the full pipeline
# &mdash; load, clean, analyse, visualise, communicate &mdash; on a dataset of your choice.
# Fill each section with your own code and findings.
#
# **How long:** this is the project; budget more than one sitting. Commit early, commit
# often.
#
# Replace every `# TODO` with real work, and write your findings in the answer cells.

# %% [markdown]
# ---
# ## Section 1 &middot; Question &amp; data
#
# A project starts with a **question**, not a dataset. State it, then load the data that
# can answer it. Edit the cell.

# %%
import pandas as pd

# TODO: load your dataset (read_csv / read_json / read_sql / an API)
# df = pd.read_csv("your_data.csv")

# first, honest look:
# print(df.shape)
# print(df.head())
# print(df.info())

# %% [markdown]
# **Write here:**
#
# - **My question:** *what, specifically, are you trying to learn?* &rarr; *your answer*
# - **The data:** *source, size, one line on how clean it is.* &rarr; *your answer*

# %% [markdown]
# ---
# ## Section 2 &middot; Clean
#
# Real data is messy; cleaning usually takes the most time. Document every choice &mdash; a
# dropped row is a decision. Edit the cell.

# %%
# TODO: clean the data. Typical moves:
# df = df.dropna(subset=["important_col"])   # or fillna(...)
# df["col"] = df["col"].str.strip()
# df = df[df["value"] >= 0]                  # remove impossible values
# print("rows before/after cleaning:", ...)

# %% [markdown]
# **Write here:**
#
# - **What I cleaned and why:** *missing values, wrong types, outliers.* &rarr; *your answer*
# - **What I deliberately kept or flagged:** &rarr; *your answer*

# %% [markdown]
# ---
# ## Section 3 &middot; Analyse
#
# Now answer the question &mdash; group, merge, summarise. Let the numbers speak. Edit the
# cell.

# %%
# TODO: the analysis that answers your question
# result = df.groupby("category")["value"].agg(["mean", "count"])
# print(result)

# %% [markdown]
# **Write here:**
#
# - **The finding:** *the one-sentence answer to your question.* &rarr; *your answer*
# - **How confident are you, and what would strengthen it?** &rarr; *your answer*

# %% [markdown]
# ---
# ## Section 4 &middot; Visualise &amp; communicate
#
# One clear, labelled, honest chart that carries your finding. Then write the takeaway a
# reader should leave with. Edit the cell.

# %%
import matplotlib.pyplot as plt

# TODO: one chart that makes your finding obvious
# fig, ax = plt.subplots()
# ...
# ax.set_title("..."); ax.set_xlabel("..."); ax.set_ylabel("...")
# plt.show()

# %% [markdown]
# **Write here:**
#
# - **One-sentence takeaway:** *what should the reader remember?* &rarr; *your answer*
# - **Limitations:** *where should we not trust this?* &rarr; *your answer*
# - **Reproducible?** *Is it under git, with a `requirements.txt`, runnable top to bottom?*
#   &rarr; *your answer*

# %% [markdown]
# ---
# ## Stretch &mdash; optional
#
# Stop here if you like; the required part is done.

# %% [markdown]
# ### Stretch &middot; Polish for presentation
#
# Turn your notebook into something a stranger could follow: add a short markdown intro,
# make sure every chart is labelled, and confirm it runs cleanly from a fresh restart
# (Runtime &rarr; Restart and run all).

# %%
# your code here

# %% [markdown]
# ---
# ## Submitting
#
# Run the cell below. It uploads this notebook straight from Colab &mdash; nothing to
# download.
#
# You need a **submit token** &mdash; one covers every lab for a month. Open
# [https://portal.latarak.com/student/submit-token](https://portal.latarak.com/student/submit-token), sign in and generate it,
# then add it **once** to Colab's Secrets panel (the &#128273; icon, left sidebar) as
# `LATARAK_TOKEN`. After that the cell reads it automatically, with no prompt. No Secrets
# panel? The cell will just ask, hiding what you type.

# %%
# --- Submit this notebook ------------------------------------------------------
# Colab only. Anywhere else, use the manual route described below this cell.
import getpass, json, urllib.request, urllib.error

PORTAL, COURSE, WEEK = "https://portal.latarak.com", "ds208", 12

try:
    from google.colab import _message
except ImportError:
    raise SystemExit(
        "Not running in Colab. Download this notebook "
        "(File > Download > Download .ipynb) and upload it at "
        "https://portal.latarak.com/course/ds208/lab/12/submit"
    )

# The LIVE notebook, including edits you have not saved yet.
nb = _message.blocking_request("get_ipynb", timeout_sec=90)["ipynb"]

# A month-long token. Store it once in Colab Secrets (key LATARAK_TOKEN) and
# this reads it with no prompt; otherwise it asks and hides what you type.
try:
    from google.colab import userdata
    token = (userdata.get("LATARAK_TOKEN") or "").strip()
except Exception:
    token = ""
if not token:
    token = getpass.getpass("Submit token (hidden as you type): ").strip()

req = urllib.request.Request(
    PORTAL + "/api/labs/" + COURSE + "/submit-notebook",
    data=json.dumps({"week": WEEK, "notebook": nb}).encode(),
    headers={"Content-Type": "application/json", "Authorization": "Bearer " + token},
    method="POST",
)
try:
    with urllib.request.urlopen(req, timeout=120) as r:
        out = json.load(r)
    print("Submitted", out["course"], "week", out["week"], "for", out["student"])
    print(out["cells"], "cells,", out["executed"], "executed")
    print(out["message"])
except urllib.error.HTTPError as e:
    print("Not submitted:", json.loads(e.read()).get("error", e.reason))

# %% [markdown]
# Prefer to do it by hand? **File &rarr; Download &rarr; Download .ipynb**, then go to the
# [Week 12 submission page](https://portal.latarak.com/course/ds208/lab/12/submit) and upload it.
#
# Re-submitting replaces your previous attempt; the most recent version is the one kept.
